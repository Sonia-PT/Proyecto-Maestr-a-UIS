# %% [markdown]
# # ANÁLISIS DE CORRELACIONES

# %%
import pandas as pd
import numpy as np
from pandas import read_csv
from pandas import DataFrame
from scipy.stats import pearsonr
import seaborn as sns

# %% [markdown]
# ## GIRON

# %%
datos = read_csv('Giron_Lags.csv', encoding='latin-1', sep=";")
datos.isnull().sum()
# Out:
# Municipio                  0
# Año                        0
# Semana_Epi                 0
# Casos_Dengue               0
# Temp_Seca_Max_Dia_Prom     5
#                           ..
# Hum_Rel_Min_2             13
# Hum_Rel_Min_3             13
# Hum_Rel_Min_4             13
# Hum_Rel_Min_5             13
# Hum_Rel_Min_6             13
# Length: 88, dtype: int64

# %%
from sklearn.impute import KNNImputer
knnImputer = KNNImputer (missing_values=np.nan, n_neighbors=2, 
                         weights="uniform", metric="nan_euclidean")
knnImputer.fit(datos[['Temp_Seca_Max_Dia_Prom']])
datos['Temp_Seca_Max_Dia_Prom'] = knnImputer.transform(datos[['Temp_Seca_Max_Dia_Prom']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Max_Dia_Prom_1']])
datos['Temp_Seca_Max_Dia_Prom_1'] = knnImputer.transform(datos[['Temp_Seca_Max_Dia_Prom_1']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Max_Dia_Prom_2']])
datos['Temp_Seca_Max_Dia_Prom_2'] = knnImputer.transform(datos[['Temp_Seca_Max_Dia_Prom_2']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Max_Dia_Prom_3']])
datos['Temp_Seca_Max_Dia_Prom_3'] = knnImputer.transform(datos[['Temp_Seca_Max_Dia_Prom_3']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Max_Dia_Prom_4']])
datos['Temp_Seca_Max_Dia_Prom_4'] = knnImputer.transform(datos[['Temp_Seca_Max_Dia_Prom_4']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Max_Dia_Prom_5']])
datos['Temp_Seca_Max_Dia_Prom_5'] = knnImputer.transform(datos[['Temp_Seca_Max_Dia_Prom_5']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Max_Dia_Prom_6']])
datos['Temp_Seca_Max_Dia_Prom_6'] = knnImputer.transform(datos[['Temp_Seca_Max_Dia_Prom_6']]).ravel()

knnImputer.fit(datos[['Temp_Seca_Max_Sem']])
datos['Temp_Seca_Max_Sem'] = knnImputer.transform(datos[['Temp_Seca_Max_Sem']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Max_Sem_1']])
datos['Temp_Seca_Max_Sem_1'] = knnImputer.transform(datos[['Temp_Seca_Max_Sem_1']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Max_Sem_2']])
datos['Temp_Seca_Max_Sem_2'] = knnImputer.transform(datos[['Temp_Seca_Max_Sem_2']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Max_Sem_3']])
datos['Temp_Seca_Max_Sem_3'] = knnImputer.transform(datos[['Temp_Seca_Max_Sem_3']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Max_Sem_4']])
datos['Temp_Seca_Max_Sem_4'] = knnImputer.transform(datos[['Temp_Seca_Max_Sem_4']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Max_Sem_5']])
datos['Temp_Seca_Max_Sem_5'] = knnImputer.transform(datos[['Temp_Seca_Max_Sem_5']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Max_Sem_6']])
datos['Temp_Seca_Max_Sem_6'] = knnImputer.transform(datos[['Temp_Seca_Max_Sem_6']]).ravel()

knnImputer.fit(datos[['Temp_Seca_Min_Dia_Prom']])
datos['Temp_Seca_Min_Dia_Prom'] = knnImputer.transform(datos[['Temp_Seca_Min_Dia_Prom']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Min_Dia_Prom_1']])
datos['Temp_Seca_Min_Dia_Prom_1'] = knnImputer.transform(datos[['Temp_Seca_Min_Dia_Prom_1']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Min_Dia_Prom_2']])
datos['Temp_Seca_Min_Dia_Prom_2'] = knnImputer.transform(datos[['Temp_Seca_Min_Dia_Prom_2']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Min_Dia_Prom_3']])
datos['Temp_Seca_Min_Dia_Prom_3'] = knnImputer.transform(datos[['Temp_Seca_Min_Dia_Prom_3']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Min_Dia_Prom_4']])
datos['Temp_Seca_Min_Dia_Prom_4'] = knnImputer.transform(datos[['Temp_Seca_Min_Dia_Prom_4']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Min_Dia_Prom_5']])
datos['Temp_Seca_Min_Dia_Prom_5'] = knnImputer.transform(datos[['Temp_Seca_Min_Dia_Prom_5']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Min_Dia_Prom_6']])
datos['Temp_Seca_Min_Dia_Prom_6'] = knnImputer.transform(datos[['Temp_Seca_Min_Dia_Prom_6']]).ravel()

knnImputer.fit(datos[['Temp_Seca_Min_Sem']])
datos['Temp_Seca_Min_Sem'] = knnImputer.transform(datos[['Temp_Seca_Min_Sem']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Min_Sem_1']])
datos['Temp_Seca_Min_Sem_1'] = knnImputer.transform(datos[['Temp_Seca_Min_Sem_1']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Min_Sem_2']])
datos['Temp_Seca_Min_Sem_2'] = knnImputer.transform(datos[['Temp_Seca_Min_Sem_2']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Min_Sem_3']])
datos['Temp_Seca_Min_Sem_3'] = knnImputer.transform(datos[['Temp_Seca_Min_Sem_3']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Min_Sem_4']])
datos['Temp_Seca_Min_Sem_4'] = knnImputer.transform(datos[['Temp_Seca_Min_Sem_4']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Min_Sem_5']])
datos['Temp_Seca_Min_Sem_5'] = knnImputer.transform(datos[['Temp_Seca_Min_Sem_5']]).ravel()
knnImputer.fit(datos[['Temp_Seca_Min_Sem_6']])
datos['Temp_Seca_Min_Sem_6'] = knnImputer.transform(datos[['Temp_Seca_Min_Sem_6']]).ravel()

knnImputer.fit(datos[['Prom_Dia_Preci']])
datos['Prom_Dia_Preci'] = knnImputer.transform(datos[['Prom_Dia_Preci']]).ravel()
knnImputer.fit(datos[['Prom_Dia_Preci_1']])
datos['Prom_Dia_Preci_1'] = knnImputer.transform(datos[['Prom_Dia_Preci_1']]).ravel()
knnImputer.fit(datos[['Prom_Dia_Preci_2']])
datos['Prom_Dia_Preci_2'] = knnImputer.transform(datos[['Prom_Dia_Preci_2']]).ravel()
knnImputer.fit(datos[['Prom_Dia_Preci_3']])
datos['Prom_Dia_Preci_3'] = knnImputer.transform(datos[['Prom_Dia_Preci_3']]).ravel()
knnImputer.fit(datos[['Prom_Dia_Preci_4']])
datos['Prom_Dia_Preci_4'] = knnImputer.transform(datos[['Prom_Dia_Preci_4']]).ravel()
knnImputer.fit(datos[['Prom_Dia_Preci_5']])
datos['Prom_Dia_Preci_5'] = knnImputer.transform(datos[['Prom_Dia_Preci_5']]).ravel()
knnImputer.fit(datos[['Prom_Dia_Preci_6']])
datos['Prom_Dia_Preci_6'] = knnImputer.transform(datos[['Prom_Dia_Preci_6']]).ravel()

knnImputer.fit(datos[['Total_Preci_Sem']])
datos['Total_Preci_Sem'] = knnImputer.transform(datos[['Total_Preci_Sem']]).ravel()
knnImputer.fit(datos[['Total_Preci_Sem_1']])
datos['Total_Preci_Sem_1'] = knnImputer.transform(datos[['Total_Preci_Sem_1']]).ravel()
knnImputer.fit(datos[['Total_Preci_Sem_2']])
datos['Total_Preci_Sem_2'] = knnImputer.transform(datos[['Total_Preci_Sem_2']]).ravel()
knnImputer.fit(datos[['Total_Preci_Sem_3']])
datos['Total_Preci_Sem_3'] = knnImputer.transform(datos[['Total_Preci_Sem_3']]).ravel()
knnImputer.fit(datos[['Total_Preci_Sem_4']])
datos['Total_Preci_Sem_4'] = knnImputer.transform(datos[['Total_Preci_Sem_4']]).ravel()
knnImputer.fit(datos[['Total_Preci_Sem_5']])
datos['Total_Preci_Sem_5'] = knnImputer.transform(datos[['Total_Preci_Sem_5']]).ravel()
knnImputer.fit(datos[['Total_Preci_Sem_6']])
datos['Total_Preci_Sem_6'] = knnImputer.transform(datos[['Total_Preci_Sem_6']]).ravel()

knnImputer.fit(datos[['Temp_Max_Dia_Prom']])
datos['Temp_Max_Dia_Prom'] = knnImputer.transform(datos[['Temp_Max_Dia_Prom']]).ravel()
knnImputer.fit(datos[['Temp_Max_Dia_Prom_1']])
datos['Temp_Max_Dia_Prom_1'] = knnImputer.transform(datos[['Temp_Max_Dia_Prom_1']]).ravel()
knnImputer.fit(datos[['Temp_Max_Dia_Prom_2']])
datos['Temp_Max_Dia_Prom_2'] = knnImputer.transform(datos[['Temp_Max_Dia_Prom_2']]).ravel()
knnImputer.fit(datos[['Temp_Max_Dia_Prom_3']])
datos['Temp_Max_Dia_Prom_3'] = knnImputer.transform(datos[['Temp_Max_Dia_Prom_3']]).ravel()
knnImputer.fit(datos[['Temp_Max_Dia_Prom_4']])
datos['Temp_Max_Dia_Prom_4'] = knnImputer.transform(datos[['Temp_Max_Dia_Prom_4']]).ravel()
knnImputer.fit(datos[['Temp_Max_Dia_Prom_5']])
datos['Temp_Max_Dia_Prom_5'] = knnImputer.transform(datos[['Temp_Max_Dia_Prom_5']]).ravel()
knnImputer.fit(datos[['Temp_Max_Dia_Prom_6']])
datos['Temp_Max_Dia_Prom_6'] = knnImputer.transform(datos[['Temp_Max_Dia_Prom_6']]).ravel()

knnImputer.fit(datos[['Temp_Max_Sem']])
datos['Temp_Max_Sem'] = knnImputer.transform(datos[['Temp_Max_Sem']]).ravel()
knnImputer.fit(datos[['Temp_Max_Sem_1']])
datos['Temp_Max_Sem_1'] = knnImputer.transform(datos[['Temp_Max_Sem_1']]).ravel()
knnImputer.fit(datos[['Temp_Max_Sem_2']])
datos['Temp_Max_Sem_2'] = knnImputer.transform(datos[['Temp_Max_Sem_2']]).ravel()
knnImputer.fit(datos[['Temp_Max_Sem_3']])
datos['Temp_Max_Sem_3'] = knnImputer.transform(datos[['Temp_Max_Sem_3']]).ravel()
knnImputer.fit(datos[['Temp_Max_Sem_4']])
datos['Temp_Max_Sem_4'] = knnImputer.transform(datos[['Temp_Max_Sem_4']]).ravel()
knnImputer.fit(datos[['Temp_Max_Sem_5']])
datos['Temp_Max_Sem_5'] = knnImputer.transform(datos[['Temp_Max_Sem_5']]).ravel()
knnImputer.fit(datos[['Temp_Max_Sem_6']])
datos['Temp_Max_Sem_6'] = knnImputer.transform(datos[['Temp_Max_Sem_6']]).ravel()

knnImputer.fit(datos[['Temp_Min_Dia_Prom']])
datos['Temp_Min_Dia_Prom'] = knnImputer.transform(datos[['Temp_Min_Dia_Prom']]).ravel()
knnImputer.fit(datos[['Temp_Min_Dia_Prom_1']])
datos['Temp_Min_Dia_Prom_1'] = knnImputer.transform(datos[['Temp_Min_Dia_Prom_1']]).ravel()
knnImputer.fit(datos[['Temp_Min_Dia_Prom_2']])
datos['Temp_Min_Dia_Prom_2'] = knnImputer.transform(datos[['Temp_Min_Dia_Prom_2']]).ravel()
knnImputer.fit(datos[['Temp_Min_Dia_Prom_3']])
datos['Temp_Min_Dia_Prom_3'] = knnImputer.transform(datos[['Temp_Min_Dia_Prom_3']]).ravel()
knnImputer.fit(datos[['Temp_Min_Dia_Prom_4']])
datos['Temp_Min_Dia_Prom_4'] = knnImputer.transform(datos[['Temp_Min_Dia_Prom_4']]).ravel()
knnImputer.fit(datos[['Temp_Min_Dia_Prom_5']])
datos['Temp_Min_Dia_Prom_5'] = knnImputer.transform(datos[['Temp_Min_Dia_Prom_5']]).ravel()
knnImputer.fit(datos[['Temp_Min_Dia_Prom_6']])
datos['Temp_Min_Dia_Prom_6'] = knnImputer.transform(datos[['Temp_Min_Dia_Prom_6']]).ravel()

knnImputer.fit(datos[['Temp_Min_Sem']])
datos['Temp_Min_Sem'] = knnImputer.transform(datos[['Temp_Min_Sem']]).ravel()
knnImputer.fit(datos[['Temp_Min_Sem_1']])
datos['Temp_Min_Sem_1'] = knnImputer.transform(datos[['Temp_Min_Sem_1']]).ravel()
knnImputer.fit(datos[['Temp_Min_Sem_2']])
datos['Temp_Min_Sem_2'] = knnImputer.transform(datos[['Temp_Min_Sem_2']]).ravel()
knnImputer.fit(datos[['Temp_Min_Sem_3']])
datos['Temp_Min_Sem_3'] = knnImputer.transform(datos[['Temp_Min_Sem_3']]).ravel()
knnImputer.fit(datos[['Temp_Min_Sem_4']])
datos['Temp_Min_Sem_4'] = knnImputer.transform(datos[['Temp_Min_Sem_4']]).ravel()
knnImputer.fit(datos[['Temp_Min_Sem_5']])
datos['Temp_Min_Sem_5'] = knnImputer.transform(datos[['Temp_Min_Sem_5']]).ravel()
knnImputer.fit(datos[['Temp_Min_Sem_6']])
datos['Temp_Min_Sem_6'] = knnImputer.transform(datos[['Temp_Min_Sem_6']]).ravel()

knnImputer.fit(datos[['Hum_Rel_Max']])
datos['Hum_Rel_Max'] = knnImputer.transform(datos[['Hum_Rel_Max']]).ravel()
knnImputer.fit(datos[['Hum_Rel_Max_1']])
datos['Hum_Rel_Max_1'] = knnImputer.transform(datos[['Hum_Rel_Max_1']]).ravel()
knnImputer.fit(datos[['Hum_Rel_Max_2']])
datos['Hum_Rel_Max_2'] = knnImputer.transform(datos[['Hum_Rel_Max_2']]).ravel()
knnImputer.fit(datos[['Hum_Rel_Max_3']])
datos['Hum_Rel_Max_3'] = knnImputer.transform(datos[['Hum_Rel_Max_3']]).ravel()
knnImputer.fit(datos[['Hum_Rel_Max_4']])
datos['Hum_Rel_Max_4'] = knnImputer.transform(datos[['Hum_Rel_Max_4']]).ravel()
knnImputer.fit(datos[['Hum_Rel_Max_5']])
datos['Hum_Rel_Max_5'] = knnImputer.transform(datos[['Hum_Rel_Max_5']]).ravel()
knnImputer.fit(datos[['Hum_Rel_Max_6']])
datos['Hum_Rel_Max_6'] = knnImputer.transform(datos[['Hum_Rel_Max_6']]).ravel()

knnImputer.fit(datos[['Hum_Rel_Min']])
datos['Hum_Rel_Min'] = knnImputer.transform(datos[['Hum_Rel_Min']]).ravel()
knnImputer.fit(datos[['Hum_Rel_Min_1']])
datos['Hum_Rel_Min_1'] = knnImputer.transform(datos[['Hum_Rel_Min_1']]).ravel()
knnImputer.fit(datos[['Hum_Rel_Min_2']])
datos['Hum_Rel_Min_2'] = knnImputer.transform(datos[['Hum_Rel_Min_2']]).ravel()
knnImputer.fit(datos[['Hum_Rel_Min_3']])
datos['Hum_Rel_Min_3'] = knnImputer.transform(datos[['Hum_Rel_Min_3']]).ravel()
knnImputer.fit(datos[['Hum_Rel_Min_4']])
datos['Hum_Rel_Min_4'] = knnImputer.transform(datos[['Hum_Rel_Min_4']]).ravel()
knnImputer.fit(datos[['Hum_Rel_Min_5']])
datos['Hum_Rel_Min_5'] = knnImputer.transform(datos[['Hum_Rel_Min_5']]).ravel()
knnImputer.fit(datos[['Hum_Rel_Min_6']])
datos['Hum_Rel_Min_6'] = knnImputer.transform(datos[['Hum_Rel_Min_6']]).ravel()

# %%
datos.isnull().sum()
# Out:
# Municipio                 0
# Año                       0
# Semana_Epi                0
# Casos_Dengue              0
# Temp_Seca_Max_Dia_Prom    0
#                          ..
# Hum_Rel_Min_2             0
# Hum_Rel_Min_3             0
# Hum_Rel_Min_4             0
# Hum_Rel_Min_5             0
# Hum_Rel_Min_6             0
# Length: 88, dtype: int64

# %%
datos.head(3)
# Out:
#   Municipio   Año  Semana_Epi  Casos_Dengue  Temp_Seca_Max_Dia_Prom  \
# 0     Girón  2014           1            23                    30.2
# 1     Girón  2014           2            25                    29.8
# 2     Girón  2014           3            21                    29.7
#
#    Temp_Seca_Max_Dia_Prom_1  Temp_Seca_Max_Dia_Prom_2  \
# 0                      29.0                      29.5
# 1                      30.2                      29.0
# 2                      29.8                      30.2
#
#    Temp_Seca_Max_Dia_Prom_3  Temp_Seca_Max_Dia_Prom_4  \
# 0                      29.9                      28.9
# 1                      29.5                      29.9
# 2                      29.0                      29.5
#
#    Temp_Seca_Max_Dia_Prom_5  ...  Hum_Rel_Max_4  Hum_Rel_Max_5  Hum_Rel_Max_6  \
# 0                      27.5  ...           91.7           91.4           89.9
# 1                      28.9  ...           93.0           91.7           91.4
# ...

# %%
datos.describe()
# Out:
#                Año  Semana_Epi  Casos_Dengue  Temp_Seca_Max_Dia_Prom  \
# count   364.000000  364.000000    364.000000              364.000000
# mean   2017.000000   26.500000     10.461538               29.452646
# std       2.002753   15.028989      9.325823                1.088704
# min    2014.000000    1.000000      0.000000               26.700000
# 25%    2015.000000   13.750000      3.000000               28.700000
# 50%    2017.000000   26.500000      7.000000               29.500000
# 75%    2019.000000   39.250000     17.000000               30.200000
# max    2020.000000   52.000000     41.000000               32.200000
#
#        Temp_Seca_Max_Dia_Prom_1  Temp_Seca_Max_Dia_Prom_2  \
# count                364.000000                364.000000
# mean                  29.454318                 29.453760
# std                    1.087559                  1.087485
# min                   26.700000                 26.700000
# ...

# %%
datos.columns
# Out:
# Index(['Municipio', 'Año', 'Semana_Epi', 'Casos_Dengue',
#        'Temp_Seca_Max_Dia_Prom', 'Temp_Seca_Max_Dia_Prom_1',
#        'Temp_Seca_Max_Dia_Prom_2', 'Temp_Seca_Max_Dia_Prom_3',
#        'Temp_Seca_Max_Dia_Prom_4', 'Temp_Seca_Max_Dia_Prom_5',
#        'Temp_Seca_Max_Dia_Prom_6', 'Temp_Seca_Max_Sem', 'Temp_Seca_Max_Sem_1',
#        'Temp_Seca_Max_Sem_2', 'Temp_Seca_Max_Sem_3', 'Temp_Seca_Max_Sem_4',
#        'Temp_Seca_Max_Sem_5', 'Temp_Seca_Max_Sem_6', 'Temp_Seca_Min_Dia_Prom',
#        'Temp_Seca_Min_Dia_Prom_1', 'Temp_Seca_Min_Dia_Prom_2',
#        'Temp_Seca_Min_Dia_Prom_3', 'Temp_Seca_Min_Dia_Prom_4',
#        'Temp_Seca_Min_Dia_Prom_5', 'Temp_Seca_Min_Dia_Prom_6',
#        'Temp_Seca_Min_Sem', 'Temp_Seca_Min_Sem_1', 'Temp_Seca_Min_Sem_2',
#        'Temp_Seca_Min_Sem_3', 'Temp_Seca_Min_Sem_4', 'Temp_Seca_Min_Sem_5',
#        'Temp_Seca_Min_Sem_6', 'Prom_Dia_Preci', 'Prom_Dia_Preci_1',
#        'Prom_Dia_Preci_2', 'Prom_Dia_Preci_3', 'Prom_Dia_Preci_4',
# ...

# %%
zero_feat=[
       'Temp_Seca_Max_Dia_Prom', 'Temp_Seca_Max_Dia_Prom_1',
       'Temp_Seca_Max_Dia_Prom_2', 'Temp_Seca_Max_Dia_Prom_3',
       'Temp_Seca_Max_Dia_Prom_4', 'Temp_Seca_Max_Dia_Prom_5',
       'Temp_Seca_Max_Dia_Prom_6', 'Temp_Seca_Max_Sem', 'Temp_Seca_Max_Sem_1',
       'Temp_Seca_Max_Sem_2', 'Temp_Seca_Max_Sem_3', 'Temp_Seca_Max_Sem_4',
       'Temp_Seca_Max_Sem_5', 'Temp_Seca_Max_Sem_6', 'Temp_Seca_Min_Dia_Prom',
       'Temp_Seca_Min_Dia_Prom_1', 'Temp_Seca_Min_Dia_Prom_2',
       'Temp_Seca_Min_Dia_Prom_3', 'Temp_Seca_Min_Dia_Prom_4',
       'Temp_Seca_Min_Dia_Prom_5', 'Temp_Seca_Min_Dia_Prom_6',
       'Temp_Seca_Min_Sem', 'Temp_Seca_Min_Sem_1', 'Temp_Seca_Min_Sem_2',
       'Temp_Seca_Min_Sem_3', 'Temp_Seca_Min_Sem_4', 'Temp_Seca_Min_Sem_5',
       'Temp_Seca_Min_Sem_6', 'Prom_Dia_Preci', 'Prom_Dia_Preci_1',
       'Prom_Dia_Preci_2', 'Prom_Dia_Preci_3', 'Prom_Dia_Preci_4',
       'Prom_Dia_Preci_5', 'Prom_Dia_Preci_6', 'Total_Preci_Sem',
       'Total_Preci_Sem_1', 'Total_Preci_Sem_2', 'Total_Preci_Sem_3',
       'Total_Preci_Sem_4', 'Total_Preci_Sem_5', 'Total_Preci_Sem_6',
       'Temp_Max_Dia_Prom', 'Temp_Max_Dia_Prom_1', 'Temp_Max_Dia_Prom_2',
       'Temp_Max_Dia_Prom_3', 'Temp_Max_Dia_Prom_4', 'Temp_Max_Dia_Prom_5',
       'Temp_Max_Dia_Prom_6', 'Temp_Max_Sem', 'Temp_Max_Sem_1',
       'Temp_Max_Sem_2', 'Temp_Max_Sem_3', 'Temp_Max_Sem_4', 'Temp_Max_Sem_5',
       'Temp_Max_Sem_6', 'Temp_Min_Dia_Prom', 'Temp_Min_Dia_Prom_1',
       'Temp_Min_Dia_Prom_2', 'Temp_Min_Dia_Prom_3', 'Temp_Min_Dia_Prom_4',
       'Temp_Min_Dia_Prom_5', 'Temp_Min_Dia_Prom_6', 'Temp_Min_Sem',
       'Temp_Min_Sem_1', 'Temp_Min_Sem_2', 'Temp_Min_Sem_3', 'Temp_Min_Sem_4',
       'Temp_Min_Sem_5', 'Temp_Min_Sem_6', 'Hum_Rel_Max', 'Hum_Rel_Max_1',
       'Hum_Rel_Max_2', 'Hum_Rel_Max_3', 'Hum_Rel_Max_4', 'Hum_Rel_Max_5',
       'Hum_Rel_Max_6', 'Hum_Rel_Min', 'Hum_Rel_Min_1', 'Hum_Rel_Min_2',
       'Hum_Rel_Min_3', 'Hum_Rel_Min_4', 'Hum_Rel_Min_5', 'Hum_Rel_Min_6']
out_feat=['Casos_Dengue']

# %%
from scipy.stats import pearsonr
for i in zero_feat:
    for j in out_feat:   
        corr, _ = pearsonr(datos[i], datos[j])
        print('La Correlación de {0} Con {1} es {2}'.format(i,j,corr))
    print('-'*60)
# Out:
# La Correlación de Temp_Seca_Max_Dia_Prom Con Casos_Dengue es 0.2034818804552685
# ------------------------------------------------------------
# La Correlación de Temp_Seca_Max_Dia_Prom_1 Con Casos_Dengue es 0.21043926003490065
# ------------------------------------------------------------
# La Correlación de Temp_Seca_Max_Dia_Prom_2 Con Casos_Dengue es 0.2043875225185308
# ------------------------------------------------------------
# La Correlación de Temp_Seca_Max_Dia_Prom_3 Con Casos_Dengue es 0.18504494787097917
# ------------------------------------------------------------
# La Correlación de Temp_Seca_Max_Dia_Prom_4 Con Casos_Dengue es 0.18766928232149196
# ------------------------------------------------------------
# La Correlación de Temp_Seca_Max_Dia_Prom_5 Con Casos_Dengue es 0.12485295715216475
# ------------------------------------------------------------
# La Correlación de Temp_Seca_Max_Dia_Prom_6 Con Casos_Dengue es 0.09334293079963132
# ...

# %%
# Find the correlations between the energy price and the rest of the features

correlaciones = datos.corr(method='pearson')
print(correlaciones['Casos_Dengue'].sort_values(ascending=False).to_string())
# Out:
# Casos_Dengue                1.000000
# Hum_Rel_Max_4               0.247883
# Hum_Rel_Max_5               0.245520
# Hum_Rel_Max_3               0.238640
# Hum_Rel_Max_6               0.237988
# Hum_Rel_Max                 0.225757
# Hum_Rel_Max_2               0.215679
# Hum_Rel_Max_1               0.213170
# Temp_Seca_Max_Dia_Prom_1    0.210439
# Temp_Seca_Max_Dia_Prom_2    0.204388
# Temp_Seca_Max_Dia_Prom      0.203482
# Temp_Max_Dia_Prom_1         0.200619
# Temp_Max_Dia_Prom           0.195877
# Temp_Seca_Max_Dia_Prom_4    0.187669
# Temp_Seca_Max_Dia_Prom_3    0.185045
# Temp_Max_Dia_Prom_2         0.184313
# Temp_Seca_Max_Sem           0.165881
# Temp_Seca_Max_Sem_1         0.163803
# Temp_Seca_Max_Sem_2         0.158611
# Temp_Max_Dia_Prom_4         0.151395
# Temp_Max_Dia_Prom_3         0.149295
# Temp_Max_Sem                0.138495
# Temp_Seca_Max_Sem_4         0.137469
# Temp_Seca_Max_Sem_3         0.134639
# Temp_Max_Sem_2              0.129298
# ...
