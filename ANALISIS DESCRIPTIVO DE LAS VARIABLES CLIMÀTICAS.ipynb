# %%
import numpy as np
import pandas as pd
from pandas import read_csv
from pandas import DataFrame
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib as mpl

# %%
Barranca = read_csv('Barrancabermeja_Lags.csv', encoding='latin-1', sep=";")
Barranca.columns
# Out:
# Index(['Municipio', 'Año', 'Semana_Epi', 'Casos_Dengue',
#        'Temp_Seca_Max_Dia_Prom', 'Temp_Seca_Max_Dia_Prom_1',
#        'Temp_Seca_Max_Dia_Prom_2', 'Temp_Seca_Max_Dia_Prom_3',
#        'Temp_Seca_Max_Dia_Prom_4', 'Temp_Seca_Max_Dia_Prom_5',
#        'Temp_Seca_Max_Dia_Prom_6', 'Temp_Seca_Max_Sem', 'Temp_Seca_Max_Sem_1',
#        'Temp_Seca_Max_Sem_2', 'Temp_Seca_Max_Sem_3', 'Temp_Seca_Max_Sem_4',
#        'Temp_Seca_Max_Sem_5', 'Temp_Seca_Max_Sem_6', 'Temp_Seca_Min_Dia_Prom',
#        'Temp_Seca_Min_Dia_Prom_1', 'Temp_Seca_Min_Dia_Prom_2',
#        'Temp_Seca_Min_Dia_Prom_3', 'Temp_Seca_Min_Dia_Prom_4',
#        'Temp_Seca_Min_Dia_Prom_5', 'Temp_Seca_Min_Dia_Prom_6',
#        'Temp_Seca_Min_Sem', 'Temp_Seca_Min_Sem_1', 'Temp_Seca_Min_Sem_2',
#        'Temp_Seca_Min_Sem_3', 'Temp_Seca_Min_Sem_4', 'Temp_Seca_Min_Sem_5',
#        'Temp_Seca_Min_Sem_6', 'Prom_Dia_Preci', 'Prom_Dia_Preci_1',
#        'Prom_Dia_Preci_2', 'Prom_Dia_Preci_3', 'Prom_Dia_Preci_4',
# ...

# %%
Barranca = Barranca.drop(['Municipio', 'Año', 'Semana_Epi', 'Temp_Seca_Max_Dia_Prom_1',
       'Temp_Seca_Max_Dia_Prom_2', 'Temp_Seca_Max_Dia_Prom_3', 'Temp_Seca_Max_Dia_Prom_4','Temp_Seca_Max_Dia_Prom_5',
       'Temp_Seca_Max_Dia_Prom_6','Temp_Seca_Max_Sem_1','Temp_Seca_Max_Sem_2', 'Temp_Seca_Max_Sem_3', 'Temp_Seca_Max_Sem_4',
       'Temp_Seca_Max_Sem_5', 'Temp_Seca_Max_Sem_6','Temp_Seca_Min_Dia_Prom_1', 'Temp_Seca_Min_Dia_Prom_2',
       'Temp_Seca_Min_Dia_Prom_3', 'Temp_Seca_Min_Dia_Prom_4','Temp_Seca_Min_Dia_Prom_5', 'Temp_Seca_Min_Dia_Prom_6',
       'Temp_Seca_Min_Sem_1', 'Temp_Seca_Min_Sem_2','Temp_Seca_Min_Sem_3', 'Temp_Seca_Min_Sem_4', 'Temp_Seca_Min_Sem_5',
       'Temp_Seca_Min_Sem_6', 'Prom_Dia_Preci_1','Prom_Dia_Preci_2', 'Prom_Dia_Preci_3', 'Prom_Dia_Preci_4',
       'Prom_Dia_Preci_5', 'Prom_Dia_Preci_6','Total_Preci_Sem_1', 'Total_Preci_Sem_2', 'Total_Preci_Sem_3',
       'Total_Preci_Sem_4', 'Total_Preci_Sem_5', 'Total_Preci_Sem_6','Temp_Max_Dia_Prom_1', 'Temp_Max_Dia_Prom_2',
       'Temp_Max_Dia_Prom_3', 'Temp_Max_Dia_Prom_4', 'Temp_Max_Dia_Prom_5','Temp_Max_Dia_Prom_6', 'Temp_Max_Sem_1',
       'Temp_Max_Sem_2', 'Temp_Max_Sem_3', 'Temp_Max_Sem_4', 'Temp_Max_Sem_5', 'Temp_Max_Sem_6', 'Temp_Min_Dia_Prom_1',
       'Temp_Min_Dia_Prom_2', 'Temp_Min_Dia_Prom_3', 'Temp_Min_Dia_Prom_4','Temp_Min_Dia_Prom_5', 'Temp_Min_Dia_Prom_6',
       'Temp_Min_Sem_1', 'Temp_Min_Sem_2', 'Temp_Min_Sem_3', 'Temp_Min_Sem_4', 'Temp_Min_Sem_5', 'Temp_Min_Sem_6',
       'Hum_Rel_Max_1','Hum_Rel_Max_2', 'Hum_Rel_Max_3', 'Hum_Rel_Max_4', 'Hum_Rel_Max_5','Hum_Rel_Max_6',
       'Hum_Rel_Min_1', 'Hum_Rel_Min_2','Hum_Rel_Min_3', 'Hum_Rel_Min_4', 'Hum_Rel_Min_5', 'Hum_Rel_Min_6'],axis=1)
Barranca.columns
# Out:
# Index(['Casos_Dengue', 'Temp_Seca_Max_Dia_Prom', 'Temp_Seca_Max_Sem',
#        'Temp_Seca_Min_Dia_Prom', 'Temp_Seca_Min_Sem', 'Prom_Dia_Preci',
#        'Total_Preci_Sem', 'Temp_Max_Dia_Prom', 'Temp_Max_Sem',
#        'Temp_Min_Dia_Prom', 'Temp_Min_Sem', 'Hum_Rel_Max', 'Hum_Rel_Min'],
#       dtype='object')

# %%
Barranca.isnull().sum()
# Out:
# Casos_Dengue               0
# Temp_Seca_Max_Dia_Prom     0
# Temp_Seca_Max_Sem          0
# Temp_Seca_Min_Dia_Prom     0
# Temp_Seca_Min_Sem          0
# Prom_Dia_Preci             0
# Total_Preci_Sem            0
# Temp_Max_Dia_Prom          0
# Temp_Max_Sem               0
# Temp_Min_Dia_Prom          0
# Temp_Min_Sem               0
# Hum_Rel_Max               23
# Hum_Rel_Min               28
# dtype: int64

# %%
from sklearn.impute import KNNImputer
knnImputer = KNNImputer (missing_values=np.nan, n_neighbors=2, 
                         weights="uniform", metric="nan_euclidean")
# Ajustamos el modelo e imputamos los missing values
knnImputer.fit(Barranca[['Hum_Rel_Max']])
Barranca['Hum_Rel_Max'] = knnImputer.transform(Barranca[['Hum_Rel_Max']]).ravel()

knnImputer.fit(Barranca[['Hum_Rel_Min']])
Barranca['Hum_Rel_Min'] = knnImputer.transform(Barranca[['Hum_Rel_Min']]).ravel()

# %%
Barranca.isnull().sum()
# Out:
# Casos_Dengue              0
# Temp_Seca_Max_Dia_Prom    0
# Temp_Seca_Max_Sem         0
# Temp_Seca_Min_Dia_Prom    0
# Temp_Seca_Min_Sem         0
# Prom_Dia_Preci            0
# Total_Preci_Sem           0
# Temp_Max_Dia_Prom         0
# Temp_Max_Sem              0
# Temp_Min_Dia_Prom         0
# Temp_Min_Sem              0
# Hum_Rel_Max               0
# Hum_Rel_Min               0
# dtype: int64

# %%
Barranca.describe()
# Out:
#        Casos_Dengue  Temp_Seca_Max_Dia_Prom  Temp_Seca_Max_Sem  \
# count    624.000000              624.000000         624.000000
# mean      10.990385               31.837804          33.289904
# std       12.628024                1.074327           0.916153
# min        0.000000               28.400000          28.400000
# 25%        2.000000               31.200000          32.800000
# 50%        5.000000               31.900000          33.400000
# 75%       17.000000               32.600000          33.800000
# max       60.000000               35.100000          37.600000
#
#        Temp_Seca_Min_Dia_Prom  Temp_Seca_Min_Sem  Prom_Dia_Preci  \
# count              624.000000         624.000000      624.000000
# mean                24.639247          23.552885        8.401763
# std                  0.677239           0.781585        7.955072
# min                 22.800000          21.000000        0.000000
# 25%                 24.192500          23.000000        1.755000
# ...

# %%
plt.figure(figsize=(14,8))
plt.subplots_adjust(hspace=0.4, wspace=0.1)

plt.subplot(3, 2, 1)
plt.title('Temperatura Seca Máxima - Barrancabermeja' )
green_patch = mpatches.Patch(color='dodgerblue', label="Temp_Seca_Max_Dia_Prom")
red_patch = mpatches.Patch(color='red', label="Temp_Seca_Max_Sem")
plt.legend(handles=[green_patch, red_patch])
plt.plot(Barranca["Temp_Seca_Max_Dia_Prom"], marker='.', color= 'dodgerblue', label="Temp_Seca_Max_Dia_Prom")
plt.plot(Barranca["Temp_Seca_Max_Sem"], color= 'red', label="Temp_Seca_Max_Sem")
plt.xlabel("Semanas")
plt.ylabel("ºC")
plt.grid(True)

plt.subplot(3, 2, 2)
plt.title('Temperatura Seca Mínima - Barrancabermeja' )
green_patch = mpatches.Patch(color='dodgerblue', label="Temp_Seca_Min_Dia_Prom")
red_patch = mpatches.Patch(color='red', label="Temp_Seca_Min_Sem")
plt.legend(handles=[green_patch, red_patch])
plt.plot(Barranca["Temp_Seca_Min_Dia_Prom"], marker='.', color= 'dodgerblue', label="Temp_Seca_Min_Dia_Prom")
plt.plot(Barranca["Temp_Seca_Min_Sem"], color= 'red', label="Temp_Seca_Min_Sem")
plt.xlabel("Semanas")
plt.ylabel("ºC")
plt.grid(True)

plt.subplot(3, 2, 3)
plt.title('Temperatura Máxima - Barrancabermeja' )
green_patch = mpatches.Patch(color='dodgerblue', label="Temp_Max_Dia_Prom")
red_patch = mpatches.Patch(color='red', label="Temp_Max_Sem")
plt.legend(handles=[green_patch, red_patch])
plt.plot(Barranca["Temp_Max_Dia_Prom"], marker='.', color= 'dodgerblue', label="Temp_Max_Dia_Prom")
plt.plot(Barranca["Temp_Max_Sem"], color= 'red', label="Temp_Max_Sem")
plt.xlabel("Semanas")
plt.ylabel("ºC")
plt.grid(True)

plt.subplot(3, 2, 4)
plt.title('Temperatura Mínima - Barrancabermeja' )
green_patch = mpatches.Patch(color='dodgerblue', label="Temp_Min_Dia_Prom")
red_patch = mpatches.Patch(color='red', label="Temp_Min_Sem")
plt.legend(handles=[green_patch, red_patch])
plt.plot(Barranca["Temp_Min_Dia_Prom"], marker='.', color= 'dodgerblue', label="Temp_Min_Dia_Prom")
plt.plot(Barranca["Temp_Min_Sem"], color= 'red', label="Temp_Min_Sem")
plt.xlabel("Semanas")
plt.ylabel("ºC")
plt.grid(True)

plt.subplot(3, 2, 5)
plt.title('Precipitaciones - Barrancabermeja' )
green_patch = mpatches.Patch(color='dodgerblue', label="Prom_Dia_Preci")
red_patch = mpatches.Patch(color='red', label="Total_Preci_Sem")
plt.legend(handles=[green_patch, red_patch])
plt.plot(Barranca["Prom_Dia_Preci"], marker='.', color= 'dodgerblue', label="Prom_Dia_Preci")
plt.plot(Barranca["Total_Preci_Sem"], color= 'red', label="Total_Preci_Sem")
plt.xlabel("Semanas")
plt.ylabel("Lt/m2")
plt.grid(True)

plt.subplot(3, 2, 6)
plt.title('Humedad Relativa - Barrancabermeja' )
green_patch = mpatches.Patch(color='dodgerblue', label="Hum_Rel_Max")
red_patch = mpatches.Patch(color='red', label="Hum_Rel_Min")
plt.legend(handles=[green_patch, red_patch])
plt.plot(Barranca["Hum_Rel_Max"], marker='.', color= 'dodgerblue', label="Hum_Rel_Max")
plt.plot(Barranca["Hum_Rel_Min"], color= 'red', label="Hum_Rel_Min")
plt.xlabel("Semanas")
plt.ylabel("%")
plt.grid(True)

plt.show()

# %% [markdown]
# # GIRON

# %%
Giron = read_csv('Giron_Lags.csv', encoding='latin-1', sep=";")
Giron.columns
# Out:
# Index(['Municipio', 'Año', 'Semana_Epi', 'Casos_Dengue',
#        'Temp_Seca_Max_Dia_Prom', 'Temp_Seca_Max_Dia_Prom_1',
#        'Temp_Seca_Max_Dia_Prom_2', 'Temp_Seca_Max_Dia_Prom_3',
#        'Temp_Seca_Max_Dia_Prom_4', 'Temp_Seca_Max_Dia_Prom_5',
#        'Temp_Seca_Max_Dia_Prom_6', 'Temp_Seca_Max_Sem', 'Temp_Seca_Max_Sem_1',
#        'Temp_Seca_Max_Sem_2', 'Temp_Seca_Max_Sem_3', 'Temp_Seca_Max_Sem_4',
#        'Temp_Seca_Max_Sem_5', 'Temp_Seca_Max_Sem_6', 'Temp_Seca_Min_Dia_Prom',
#        'Temp_Seca_Min_Dia_Prom_1', 'Temp_Seca_Min_Dia_Prom_2',
#        'Temp_Seca_Min_Dia_Prom_3', 'Temp_Seca_Min_Dia_Prom_4',
#        'Temp_Seca_Min_Dia_Prom_5', 'Temp_Seca_Min_Dia_Prom_6',
#        'Temp_Seca_Min_Sem', 'Temp_Seca_Min_Sem_1', 'Temp_Seca_Min_Sem_2',
#        'Temp_Seca_Min_Sem_3', 'Temp_Seca_Min_Sem_4', 'Temp_Seca_Min_Sem_5',
#        'Temp_Seca_Min_Sem_6', 'Prom_Dia_Preci', 'Prom_Dia_Preci_1',
#        'Prom_Dia_Preci_2', 'Prom_Dia_Preci_3', 'Prom_Dia_Preci_4',
# ...

# %%
Giron = Giron.drop(['Municipio', 'Año', 'Semana_Epi', 'Temp_Seca_Max_Dia_Prom_1',
       'Temp_Seca_Max_Dia_Prom_2', 'Temp_Seca_Max_Dia_Prom_3', 'Temp_Seca_Max_Dia_Prom_4','Temp_Seca_Max_Dia_Prom_5',
       'Temp_Seca_Max_Dia_Prom_6','Temp_Seca_Max_Sem_1','Temp_Seca_Max_Sem_2', 'Temp_Seca_Max_Sem_3', 'Temp_Seca_Max_Sem_4',
       'Temp_Seca_Max_Sem_5', 'Temp_Seca_Max_Sem_6','Temp_Seca_Min_Dia_Prom_1', 'Temp_Seca_Min_Dia_Prom_2',
       'Temp_Seca_Min_Dia_Prom_3', 'Temp_Seca_Min_Dia_Prom_4','Temp_Seca_Min_Dia_Prom_5', 'Temp_Seca_Min_Dia_Prom_6',
       'Temp_Seca_Min_Sem_1', 'Temp_Seca_Min_Sem_2','Temp_Seca_Min_Sem_3', 'Temp_Seca_Min_Sem_4', 'Temp_Seca_Min_Sem_5',
       'Temp_Seca_Min_Sem_6', 'Prom_Dia_Preci_1','Prom_Dia_Preci_2', 'Prom_Dia_Preci_3', 'Prom_Dia_Preci_4',
       'Prom_Dia_Preci_5', 'Prom_Dia_Preci_6','Total_Preci_Sem_1', 'Total_Preci_Sem_2', 'Total_Preci_Sem_3',
       'Total_Preci_Sem_4', 'Total_Preci_Sem_5', 'Total_Preci_Sem_6','Temp_Max_Dia_Prom_1', 'Temp_Max_Dia_Prom_2',
       'Temp_Max_Dia_Prom_3', 'Temp_Max_Dia_Prom_4', 'Temp_Max_Dia_Prom_5','Temp_Max_Dia_Prom_6', 'Temp_Max_Sem_1',
       'Temp_Max_Sem_2', 'Temp_Max_Sem_3', 'Temp_Max_Sem_4', 'Temp_Max_Sem_5', 'Temp_Max_Sem_6', 'Temp_Min_Dia_Prom_1',
       'Temp_Min_Dia_Prom_2', 'Temp_Min_Dia_Prom_3', 'Temp_Min_Dia_Prom_4','Temp_Min_Dia_Prom_5', 'Temp_Min_Dia_Prom_6',
       'Temp_Min_Sem_1', 'Temp_Min_Sem_2', 'Temp_Min_Sem_3', 'Temp_Min_Sem_4', 'Temp_Min_Sem_5', 'Temp_Min_Sem_6',
       'Hum_Rel_Max_1','Hum_Rel_Max_2', 'Hum_Rel_Max_3', 'Hum_Rel_Max_4', 'Hum_Rel_Max_5','Hum_Rel_Max_6',
       'Hum_Rel_Min_1', 'Hum_Rel_Min_2','Hum_Rel_Min_3', 'Hum_Rel_Min_4', 'Hum_Rel_Min_5', 'Hum_Rel_Min_6'],axis=1)
Giron.columns
# Out:
# Index(['Casos_Dengue', 'Temp_Seca_Max_Dia_Prom', 'Temp_Seca_Max_Sem',
#        'Temp_Seca_Min_Dia_Prom', 'Temp_Seca_Min_Sem', 'Prom_Dia_Preci',
#        'Total_Preci_Sem', 'Temp_Max_Dia_Prom', 'Temp_Max_Sem',
#        'Temp_Min_Dia_Prom', 'Temp_Min_Sem', 'Hum_Rel_Max', 'Hum_Rel_Min'],
#       dtype='object')

# %%
Giron.isnull().sum()
# Out:
# Casos_Dengue               0
# Temp_Seca_Max_Dia_Prom     5
# Temp_Seca_Max_Sem          5
# Temp_Seca_Min_Dia_Prom     5
# Temp_Seca_Min_Sem          5
# Prom_Dia_Preci             4
# Total_Preci_Sem            4
# Temp_Max_Dia_Prom         13
# Temp_Max_Sem              13
# Temp_Min_Dia_Prom         13
# Temp_Min_Sem              13
# Hum_Rel_Max               13
# Hum_Rel_Min               13
# dtype: int64

# %%
from sklearn.impute import KNNImputer
knnImputer = KNNImputer (missing_values=np.nan, n_neighbors=2, 
                         weights="uniform", metric="nan_euclidean")
knnImputer.fit(Giron[['Temp_Seca_Max_Dia_Prom']])
Giron['Temp_Seca_Max_Dia_Prom'] = knnImputer.transform(Giron[['Temp_Seca_Max_Dia_Prom']]).ravel()
knnImputer.fit(Giron[['Temp_Seca_Max_Sem']])
Giron['Temp_Seca_Max_Sem'] = knnImputer.transform(Giron[['Temp_Seca_Max_Sem']]).ravel()
knnImputer.fit(Giron[['Temp_Seca_Min_Dia_Prom']])
Giron['Temp_Seca_Min_Dia_Prom'] = knnImputer.transform(Giron[['Temp_Seca_Min_Dia_Prom']]).ravel()
knnImputer.fit(Giron[['Temp_Seca_Min_Sem']])
Giron['Temp_Seca_Min_Sem'] = knnImputer.transform(Giron[['Temp_Seca_Min_Sem']]).ravel()
knnImputer.fit(Giron[['Prom_Dia_Preci']])
Giron['Prom_Dia_Preci'] = knnImputer.transform(Giron[['Prom_Dia_Preci']]).ravel()
knnImputer.fit(Giron[['Total_Preci_Sem']])
Giron['Total_Preci_Sem'] = knnImputer.transform(Giron[['Total_Preci_Sem']]).ravel()
knnImputer.fit(Giron[['Temp_Max_Dia_Prom']])
Giron['Temp_Max_Dia_Prom'] = knnImputer.transform(Giron[['Temp_Max_Dia_Prom']]).ravel()
knnImputer.fit(Giron[['Temp_Max_Sem']])
Giron['Temp_Max_Sem'] = knnImputer.transform(Giron[['Temp_Max_Sem']]).ravel()
knnImputer.fit(Giron[['Temp_Min_Dia_Prom']])
Giron['Temp_Min_Dia_Prom'] = knnImputer.transform(Giron[['Temp_Min_Dia_Prom']]).ravel()
knnImputer.fit(Giron[['Temp_Min_Sem']])
Giron['Temp_Min_Sem'] = knnImputer.transform(Giron[['Temp_Min_Sem']]).ravel()
knnImputer.fit(Giron[['Hum_Rel_Max']])
Giron['Hum_Rel_Max'] = knnImputer.transform(Giron[['Hum_Rel_Max']]).ravel()
knnImputer.fit(Giron[['Hum_Rel_Min']])
Giron['Hum_Rel_Min'] = knnImputer.transform(Giron[['Hum_Rel_Min']]).ravel()

# %%
Giron.isnull().sum()
# Out:
# Casos_Dengue              0
# Temp_Seca_Max_Dia_Prom    0
# Temp_Seca_Max_Sem         0
# Temp_Seca_Min_Dia_Prom    0
# Temp_Seca_Min_Sem         0
# Prom_Dia_Preci            0
# Total_Preci_Sem           0
# Temp_Max_Dia_Prom         0
# Temp_Max_Sem              0
# Temp_Min_Dia_Prom         0
# Temp_Min_Sem              0
# Hum_Rel_Max               0
# Hum_Rel_Min               0
# dtype: int64

# %%
Giron.describe()
# Out:
#        Casos_Dengue  Temp_Seca_Max_Dia_Prom  Temp_Seca_Max_Sem  \
# count    364.000000              364.000000         364.000000
# mean      10.461538               29.452646          31.128691
# std        9.325823                1.088704           1.116585
# min        0.000000               26.700000          28.800000
# 25%        3.000000               28.700000          30.400000
# 50%        7.000000               29.500000          31.000000
# 75%       17.000000               30.200000          32.000000
# max       41.000000               32.200000          34.600000
#
#        Temp_Seca_Min_Dia_Prom  Temp_Seca_Min_Sem  Prom_Dia_Preci  \
# count              364.000000         364.000000      364.000000
# mean                20.769359          19.878552        2.290222
# std                  0.724051           0.836339        2.767363
# min                 16.700000          14.800000        0.000000
# 25%                 20.400000          19.600000        0.347500
# ...

# %%
plt.figure(figsize=(14,8))
plt.subplots_adjust(hspace=0.4, wspace=0.1)

plt.subplot(3, 2, 1)
plt.title('Temperatura Seca Máxima - Giron' )
green_patch = mpatches.Patch(color='dodgerblue', label="Temp_Seca_Max_Dia_Prom")
red_patch = mpatches.Patch(color='red', label="Temp_Seca_Max_Sem")
plt.legend(handles=[green_patch, red_patch])
plt.plot(Giron["Temp_Seca_Max_Dia_Prom"], marker='.', color= 'dodgerblue', label="Temp_Seca_Max_Dia_Prom")
plt.plot(Giron["Temp_Seca_Max_Sem"], color= 'red', label="Temp_Seca_Max_Sem")
plt.xlabel("Semanas")
plt.ylabel("ºC")
plt.grid(True)

plt.subplot(3, 2, 2)
plt.title('Temperatura Seca Mínima - Giron' )
green_patch = mpatches.Patch(color='dodgerblue', label="Temp_Seca_Min_Dia_Prom")
red_patch = mpatches.Patch(color='red', label="Temp_Seca_Min_Sem")
plt.legend(handles=[green_patch, red_patch])
plt.plot(Giron["Temp_Seca_Min_Dia_Prom"], marker='.', color= 'dodgerblue', label="Temp_Seca_Min_Dia_Prom")
plt.plot(Giron["Temp_Seca_Min_Sem"], color= 'red', label="Temp_Seca_Min_Sem")
plt.xlabel("Semanas")
plt.ylabel("ºC")
plt.grid(True)

plt.subplot(3, 2, 3)
plt.title('Temperatura Máxima - Giron' )
green_patch = mpatches.Patch(color='dodgerblue', label="Temp_Max_Dia_Prom")
red_patch = mpatches.Patch(color='red', label="Temp_Max_Sem")
plt.legend(handles=[green_patch, red_patch])
plt.plot(Giron["Temp_Max_Dia_Prom"], marker='.', color= 'dodgerblue', label="Temp_Max_Dia_Prom")
plt.plot(Giron["Temp_Max_Sem"], color= 'red', label="Temp_Max_Sem")
plt.xlabel("Semanas")
plt.ylabel("ºC")
plt.grid(True)

plt.subplot(3, 2, 4)
plt.title('Temperatura Mínima - Giron' )
green_patch = mpatches.Patch(color='dodgerblue', label="Temp_Min_Dia_Prom")
red_patch = mpatches.Patch(color='red', label="Temp_Min_Sem")
plt.legend(handles=[green_patch, red_patch])
plt.plot(Giron["Temp_Min_Dia_Prom"], marker='.', color= 'dodgerblue', label="Temp_Min_Dia_Prom")
plt.plot(Giron["Temp_Min_Sem"], color= 'red', label="Temp_Min_Sem")
plt.xlabel("Semanas")
plt.ylabel("ºC")
plt.grid(True)

plt.subplot(3, 2, 5)
plt.title('Precipitaciones - Giron' )
green_patch = mpatches.Patch(color='dodgerblue', label="Prom_Dia_Preci")
red_patch = mpatches.Patch(color='red', label="Total_Preci_Sem")
plt.legend(handles=[green_patch, red_patch])
plt.plot(Giron["Prom_Dia_Preci"], marker='.', color= 'dodgerblue', label="Prom_Dia_Preci")
plt.plot(Giron["Total_Preci_Sem"], color= 'red', label="Total_Preci_Sem")
plt.xlabel("Semanas")
plt.ylabel("Lt/m2")
plt.grid(True)

plt.subplot(3, 2, 6)
plt.title('Humedad Relativa - Giron' )
green_patch = mpatches.Patch(color='dodgerblue', label="Hum_Rel_Max")
red_patch = mpatches.Patch(color='red', label="Hum_Rel_Min")
plt.legend(handles=[green_patch, red_patch])
plt.plot(Giron["Hum_Rel_Max"], marker='.', color= 'dodgerblue', label="Hum_Rel_Max")
plt.plot(Giron["Hum_Rel_Min"], color= 'red', label="Hum_Rel_Min")
plt.xlabel("Semanas")
plt.ylabel("%")
plt.grid(True)

plt.show()

# %% [markdown]
# # LEBRIJA

# %%
Lebrija = read_csv('Lebrija_Lags.csv', encoding='latin-1', sep=";")
Lebrija.columns
# Out:
# Index(['Municipio', 'Año', 'Semana_Epi', 'Casos_Dengue',
#        'Temp_Seca_Max_Dia_Prom', 'Temp_Seca_Max_Dia_Prom_1',
#        'Temp_Seca_Max_Dia_Prom_2', 'Temp_Seca_Max_Dia_Prom_3',
#        'Temp_Seca_Max_Dia_Prom_4', 'Temp_Seca_Max_Dia_Prom_5',
#        'Temp_Seca_Max_Dia_Prom_6', 'Temp_Seca_Max_Sem', 'Temp_Seca_Max_Sem_1',
#        'Temp_Seca_Max_Sem_2', 'Temp_Seca_Max_Sem_3', 'Temp_Seca_Max_Sem_4',
#        'Temp_Seca_Max_Sem_5', 'Temp_Seca_Max_Sem_6', 'Temp_Seca_Min_Dia_Prom',
#        'Temp_Seca_Min_Dia_Prom_1', 'Temp_Seca_Min_Dia_Prom_2',
#        'Temp_Seca_Min_Dia_Prom_3', 'Temp_Seca_Min_Dia_Prom_4',
#        'Temp_Seca_Min_Dia_Prom_5', 'Temp_Seca_Min_Dia_Prom_6',
#        'Temp_Seca_Min_Sem', 'Temp_Seca_Min_Sem_1', 'Temp_Seca_Min_Sem_2',
#        'Temp_Seca_Min_Sem_3', 'Temp_Seca_Min_Sem_4', 'Temp_Seca_Min_Sem_5',
#        'Temp_Seca_Min_Sem_6', 'Prom_Dia_Preci', 'Prom_Dia_Preci_1',
#        'Prom_Dia_Preci_2', 'Prom_Dia_Preci_3', 'Prom_Dia_Preci_4',
# ...

# %%
Lebrija = Lebrija.drop(['Municipio', 'Año', 'Semana_Epi', 'Temp_Seca_Max_Dia_Prom_1',
       'Temp_Seca_Max_Dia_Prom_2', 'Temp_Seca_Max_Dia_Prom_3', 'Temp_Seca_Max_Dia_Prom_4','Temp_Seca_Max_Dia_Prom_5',
       'Temp_Seca_Max_Dia_Prom_6','Temp_Seca_Max_Sem_1','Temp_Seca_Max_Sem_2', 'Temp_Seca_Max_Sem_3', 'Temp_Seca_Max_Sem_4',
       'Temp_Seca_Max_Sem_5', 'Temp_Seca_Max_Sem_6','Temp_Seca_Min_Dia_Prom_1', 'Temp_Seca_Min_Dia_Prom_2',
       'Temp_Seca_Min_Dia_Prom_3', 'Temp_Seca_Min_Dia_Prom_4','Temp_Seca_Min_Dia_Prom_5', 'Temp_Seca_Min_Dia_Prom_6',
       'Temp_Seca_Min_Sem_1', 'Temp_Seca_Min_Sem_2','Temp_Seca_Min_Sem_3', 'Temp_Seca_Min_Sem_4', 'Temp_Seca_Min_Sem_5',
       'Temp_Seca_Min_Sem_6', 'Prom_Dia_Preci_1','Prom_Dia_Preci_2', 'Prom_Dia_Preci_3', 'Prom_Dia_Preci_4',
       'Prom_Dia_Preci_5', 'Prom_Dia_Preci_6','Total_Preci_Sem_1', 'Total_Preci_Sem_2', 'Total_Preci_Sem_3',
       'Total_Preci_Sem_4', 'Total_Preci_Sem_5', 'Total_Preci_Sem_6','Temp_Max_Dia_Prom_1', 'Temp_Max_Dia_Prom_2',
       'Temp_Max_Dia_Prom_3', 'Temp_Max_Dia_Prom_4', 'Temp_Max_Dia_Prom_5','Temp_Max_Dia_Prom_6', 'Temp_Max_Sem_1',
       'Temp_Max_Sem_2', 'Temp_Max_Sem_3', 'Temp_Max_Sem_4', 'Temp_Max_Sem_5', 'Temp_Max_Sem_6', 'Temp_Min_Dia_Prom_1',
       'Temp_Min_Dia_Prom_2', 'Temp_Min_Dia_Prom_3', 'Temp_Min_Dia_Prom_4','Temp_Min_Dia_Prom_5', 'Temp_Min_Dia_Prom_6',
       'Temp_Min_Sem_1', 'Temp_Min_Sem_2', 'Temp_Min_Sem_3', 'Temp_Min_Sem_4', 'Temp_Min_Sem_5', 'Temp_Min_Sem_6'],axis=1)
Lebrija.columns
# Out:
# Index(['Casos_Dengue', 'Temp_Seca_Max_Dia_Prom', 'Temp_Seca_Max_Sem',
#        'Temp_Seca_Min_Dia_Prom', 'Temp_Seca_Min_Sem', 'Prom_Dia_Preci',
#        'Total_Preci_Sem', 'Temp_Max_Dia_Prom', 'Temp_Max_Sem',
#        'Temp_Min_Dia_Prom', 'Temp_Min_Sem'],
#       dtype='object')

# %%
Lebrija.isnull().sum()
# Out:
# Casos_Dengue              0
# Temp_Seca_Max_Dia_Prom    0
# Temp_Seca_Max_Sem         0
# Temp_Seca_Min_Dia_Prom    0
# Temp_Seca_Min_Sem         0
# Prom_Dia_Preci            0
# Total_Preci_Sem           0
# Temp_Max_Dia_Prom         0
# Temp_Max_Sem              0
# Temp_Min_Dia_Prom         0
# Temp_Min_Sem              0
# dtype: int64

# %%
Lebrija.describe()
# Out:
#        Casos_Dengue  Temp_Seca_Max_Dia_Prom  Temp_Seca_Max_Sem  \
# count    416.000000              416.000000          416.00000
# mean       3.362981               24.457212           25.97476
# std        3.804306                1.103901            1.21911
# min        0.000000               21.700000           23.00000
# 25%        1.000000               23.700000           25.20000
# 50%        2.000000               24.400000           26.00000
# 75%        5.000000               25.100000           26.60000
# max       21.000000               28.200000           30.00000
#
#        Temp_Seca_Min_Dia_Prom  Temp_Seca_Min_Sem  Prom_Dia_Preci  \
# count              416.000000         416.000000      416.000000
# mean                19.360096          18.505048        3.575457
# std                  0.650926           0.725075        4.612420
# min                 17.600000          16.000000        0.000000
# 25%                 18.900000          18.000000        0.637500
# ...

# %%
plt.figure(figsize=(14,8))
plt.subplots_adjust(hspace=0.4, wspace=0.1)

plt.subplot(3, 2, 1)
plt.title('Temperatura Seca Máxima - Lebrija' )
green_patch = mpatches.Patch(color='dodgerblue', label="Temp_Seca_Max_Dia_Prom")
red_patch = mpatches.Patch(color='red', label="Temp_Seca_Max_Sem")
plt.legend(handles=[green_patch, red_patch])
plt.plot(Lebrija["Temp_Seca_Max_Dia_Prom"], marker='.', color= 'dodgerblue', label="Temp_Seca_Max_Dia_Prom")
plt.plot(Lebrija["Temp_Seca_Max_Sem"], color= 'red', label="Temp_Seca_Max_Sem")
plt.xlabel("Semanas")
plt.ylabel("ºC")
plt.grid(True)

plt.subplot(3, 2, 2)
plt.title('Temperatura Seca Mínima - Lebrija' )
green_patch = mpatches.Patch(color='dodgerblue', label="Temp_Seca_Min_Dia_Prom")
red_patch = mpatches.Patch(color='red', label="Temp_Seca_Min_Sem")
plt.legend(handles=[green_patch, red_patch])
plt.plot(Lebrija["Temp_Seca_Min_Dia_Prom"], marker='.', color= 'dodgerblue', label="Temp_Seca_Min_Dia_Prom")
plt.plot(Lebrija["Temp_Seca_Min_Sem"], color= 'red', label="Temp_Seca_Min_Sem")
plt.xlabel("Semanas")
plt.ylabel("ºC")
plt.grid(True)

plt.subplot(3, 2, 3)
plt.title('Temperatura Máxima - Lebrija' )
green_patch = mpatches.Patch(color='dodgerblue', label="Temp_Max_Dia_Prom")
red_patch = mpatches.Patch(color='red', label="Temp_Max_Sem")
plt.legend(handles=[green_patch, red_patch])
plt.plot(Lebrija["Temp_Max_Dia_Prom"], marker='.', color= 'dodgerblue', label="Temp_Max_Dia_Prom")
plt.plot(Lebrija["Temp_Max_Sem"], color= 'red', label="Temp_Max_Sem")
plt.xlabel("Semanas")
plt.ylabel("ºC")
plt.grid(True)

plt.subplot(3, 2, 4)
plt.title('Temperatura Mínima - Lebrija' )
green_patch = mpatches.Patch(color='dodgerblue', label="Temp_Min_Dia_Prom")
red_patch = mpatches.Patch(color='red', label="Temp_Min_Sem")
plt.legend(handles=[green_patch, red_patch])
plt.plot(Lebrija["Temp_Min_Dia_Prom"], marker='.', color= 'dodgerblue', label="Temp_Min_Dia_Prom")
plt.plot(Lebrija["Temp_Min_Sem"], color= 'red', label="Temp_Min_Sem")
plt.xlabel("Semanas")
plt.ylabel("ºC")
plt.grid(True)

plt.subplot(3, 2, 5)
plt.title('Precipitaciones - Lebrija' )
green_patch = mpatches.Patch(color='dodgerblue', label="Prom_Dia_Preci")
red_patch = mpatches.Patch(color='red', label="Total_Preci_Sem")
plt.legend(handles=[green_patch, red_patch])
plt.plot(Lebrija["Prom_Dia_Preci"], marker='.', color= 'dodgerblue', label="Prom_Dia_Preci")
plt.plot(Lebrija["Total_Preci_Sem"], color= 'red', label="Total_Preci_Sem")
plt.xlabel("Semanas")
plt.ylabel("Lt/m2")
plt.grid(True)

plt.show()

# %% [markdown]
# # BUCARAMANGA - FLORIDA - PIEDECUESTA

# %%
Bucara = read_csv('Bucaramanga_Lags.csv', encoding='latin-1', sep=";")
Bucara.columns
# Out:
# Index(['Municipio', 'Año', 'Semana_Epi', 'Casos_Dengue', 'Prom_Dia_Preci',
#        'Prom_Dia_Preci_1', 'Prom_Dia_Preci_2', 'Prom_Dia_Preci_3',
#        'Prom_Dia_Preci_4', 'Prom_Dia_Preci_5', 'Prom_Dia_Preci_6',
#        'Total_Preci_Sem', 'Total_Preci_Sem_1', 'Total_Preci_Sem_2',
#        'Total_Preci_Sem_3', 'Total_Preci_Sem_4', 'Total_Preci_Sem_5',
#        'Total_Preci_Sem_6'],
#       dtype='object')

# %%
Bucara = Bucara.drop(['Municipio', 'Año', 'Semana_Epi', 'Prom_Dia_Preci_1','Prom_Dia_Preci_2', 'Prom_Dia_Preci_3',
                      'Prom_Dia_Preci_4','Prom_Dia_Preci_5', 'Prom_Dia_Preci_6','Total_Preci_Sem_1', 'Total_Preci_Sem_2',
                      'Total_Preci_Sem_3','Total_Preci_Sem_4', 'Total_Preci_Sem_5', 'Total_Preci_Sem_6'],axis=1)
Bucara.columns
# Out:
# Index(['Casos_Dengue', 'Prom_Dia_Preci', 'Total_Preci_Sem'], dtype='object')

# %%
Florida= read_csv('Floridablanca_Lags.csv', encoding='latin-1', sep=";")
Florida = Florida.drop(['Municipio', 'Año', 'Semana_Epi', 'Prom_Dia_Preci_1','Prom_Dia_Preci_2', 'Prom_Dia_Preci_3',
                      'Prom_Dia_Preci_4','Prom_Dia_Preci_5', 'Prom_Dia_Preci_6','Total_Preci_Sem_1', 'Total_Preci_Sem_2',
                      'Total_Preci_Sem_3','Total_Preci_Sem_4', 'Total_Preci_Sem_5', 'Total_Preci_Sem_6'],axis=1)
Florida.columns
# Out:
# Index(['Casos_Dengue', 'Prom_Dia_Preci', 'Total_Preci_Sem'], dtype='object')

# %%
Piede = read_csv('Piedecuesta_Lags.csv', encoding='latin-1', sep=";")
Piede = Piede.drop(['Municipio', 'Año', 'Semana_Epi', 'Prom_Dia_Preci_1','Prom_Dia_Preci_2', 'Prom_Dia_Preci_3',
                      'Prom_Dia_Preci_4','Prom_Dia_Preci_5', 'Prom_Dia_Preci_6','Total_Preci_Sem_1', 'Total_Preci_Sem_2',
                      'Total_Preci_Sem_3','Total_Preci_Sem_4', 'Total_Preci_Sem_5', 'Total_Preci_Sem_6'],axis=1)
Piede.columns
# Out:
# Index(['Casos_Dengue', 'Prom_Dia_Preci', 'Total_Preci_Sem'], dtype='object')

# %%
Bucara.isnull().sum()
# Out:
# Casos_Dengue       0
# Prom_Dia_Preci     0
# Total_Preci_Sem    0
# dtype: int64

# %%
Florida.isnull().sum()
# Out:
# Casos_Dengue       0
# Prom_Dia_Preci     0
# Total_Preci_Sem    0
# dtype: int64

# %%
Piede.isnull().sum()
# Out:
# Casos_Dengue       0
# Prom_Dia_Preci     6
# Total_Preci_Sem    6
# dtype: int64

# %%
from sklearn.impute import KNNImputer
knnImputer = KNNImputer (missing_values=np.nan, n_neighbors=2, 
                         weights="uniform", metric="nan_euclidean")
knnImputer.fit(Piede[['Prom_Dia_Preci']])
Piede['Prom_Dia_Preci'] = knnImputer.transform(Piede[['Prom_Dia_Preci']]).ravel()
knnImputer.fit(Piede[['Total_Preci_Sem']])
Piede['Total_Preci_Sem'] = knnImputer.transform(Piede[['Total_Preci_Sem']]).ravel()

# %%
Piede.isnull().sum()
# Out:
# Casos_Dengue       0
# Prom_Dia_Preci     0
# Total_Preci_Sem    0
# dtype: int64

# %%
Bucara.describe()
# Out:
#        Casos_Dengue  Prom_Dia_Preci  Total_Preci_Sem
# count    624.000000      624.000000       624.000000
# mean      50.158654        3.523494        24.715545
# std       46.559603        4.041911        28.384120
# min        1.000000        0.000000         0.000000
# 25%       17.000000        0.682500         4.750000
# 50%       32.500000        2.225000        15.600000
# 75%       74.000000        4.752500        33.275000
# max      272.000000       35.210000       246.500000

# %%
Florida.describe()
# Out:
#        Casos_Dengue  Prom_Dia_Preci  Total_Preci_Sem
# count    624.000000      624.000000       624.000000
# mean      28.556090        4.929744        34.583333
# std       28.261166        4.885494        34.293568
# min        0.000000        0.000000         0.000000
# 25%        9.000000        1.367500         9.675000
# 50%       18.000000        3.680000        25.750000
# 75%       40.000000        6.822500        47.850000
# max      160.000000       40.010000       280.100000

# %%
Piede.describe()
# Out:
#        Casos_Dengue  Prom_Dia_Preci  Total_Preci_Sem
# count    676.000000      676.000000       676.000000
# mean      11.378698        4.594716        32.229403
# std       10.470067        5.048707        35.426193
# min        0.000000        0.000000         0.000000
# 25%        4.000000        0.960000         6.700000
# 50%        8.000000        3.010000        21.100000
# 75%       17.000000        6.440000        45.425000
# max       55.000000       34.440000       241.100000

# %%
plt.figure(figsize=(14,8))
plt.subplots_adjust(hspace=0.4, wspace=0.2)

plt.subplot(3, 2, 1)
plt.title('Precipitaciones promedio - Bucaramanga' )
plt.plot(Bucara["Prom_Dia_Preci"], marker='.', color= 'dodgerblue', label="Prom_Dia_Preci")
plt.xlabel("Semanas")
plt.ylabel("Lt/m2")
plt.grid(True)

plt.subplot(3, 2, 2)
plt.title('Precipitaciones Totales - Bucaramanga' )
plt.plot(Bucara["Total_Preci_Sem"], color= 'red', label="Total_Preci_Sem")
plt.xlabel("Semanas")
plt.ylabel("Lt/m2")
plt.grid(True)

plt.subplot(3, 2, 3)
plt.title('Precipitaciones promedio - Floridablanca' )
plt.plot(Florida["Prom_Dia_Preci"], marker='.', color= 'dodgerblue', label="Prom_Dia_Preci")
plt.xlabel("Semanas")
plt.ylabel("Lt/m2")
plt.grid(True)

plt.subplot(3, 2, 4)
plt.title('Precipitaciones Totales - Floridablanca' )
plt.plot(Florida["Total_Preci_Sem"], color= 'red', label="Total_Preci_Sem")
plt.xlabel("Semanas")
plt.ylabel("Lt/m2")
plt.grid(True)

plt.subplot(3, 2, 5)
plt.title('Precipitaciones promedio - Piedecuesta' )
plt.plot(Piede["Prom_Dia_Preci"], marker='.', color= 'dodgerblue', label="Prom_Dia_Preci")
plt.xlabel("Semanas")
plt.ylabel("Lt/m2")
plt.grid(True)

plt.subplot(3, 2, 6)
plt.title('Precipitaciones Totales - Piedecuesta' )
plt.plot(Piede["Total_Preci_Sem"], color= 'red', label="Total_Preci_Sem")
plt.xlabel("Semanas")
plt.ylabel("Lt/m2")
plt.grid(True)

plt.show()
